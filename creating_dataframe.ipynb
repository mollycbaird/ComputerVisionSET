# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import PIL
from PIL import Image

# %% [markdown]
# ### Pillow resource:
#
# https://machinelearningmastery.com/how-to-load-and-manipulate-images-for-deep-learning-in-python-with-pil-pillow/

# %% [markdown]
# You may need to install Pillow, can be done via pip:

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.7/site-packages (6.2.0)

# %% [markdown]
# Let's look at one image and its size:

# %%
# load the image
image = Image.open('./attachments/SET0007.jpg')

# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)

# show the image
image.show()
# Out:
# JPEG
# RGB
# (2544, 3296)

# %% [markdown]
# Let's crop it so that all shapes can still be seen on each card, but we cut out some white space common to all cards. Doing the cropping so that the dimensions are same as bee image set, in case I want to try new images on neural nets that were trained on a different set of images entirely.

# %%
# create a cropped image
cropped = image.crop((60, 20, 950, 643))
# show cropped image
cropped.show()

# %% [markdown]
# Now we resize to save computational space:

# %%
basewidth = 50

wpercent = (basewidth / float(cropped.size[0]))
hsize = int((float(cropped.size[1]) * float(wpercent)))
img = cropped.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
img.show()

# %%
img.size
# Out:
# (50, 35)

# %%
cropped.size
# Out:
# (890, 623)

# %%
img_vec = np.array(img)
img_vec.shape
# Out:
# (35, 50, 3)

# %%
img_vec
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
img_again = Image.fromarray(img_vec)

# %%
img_again.show()

# %%
practice = np.array([[1, 'a'],[2,'b'],[3,'c']])

# %%
practice[:,1]
# Out:
# array(['a', 'b', 'c'], dtype='<U21')

# %%
practice
# Out:
# array([['1', 'a'],
#        ['2', 'b'],
#        ['3', 'c']], dtype='<U21')

# %% [markdown]
# https://note.nkmk.me/en/python-numpy-image-processing/

# %% [markdown]
# ## Iterating through a folder

# %%
image_df = pd.DataFrame(img_vec_flat)

# creating color column
image_df.insert(loc=0, column='color', value='red')

# creating shape column
image_df.insert(loc=0, column='shape', value='squiggle')

# creating number column
image_df.insert(loc=0, column='number', value=3)

# creating fill column
image_df.insert(loc=0, column='fill', value='striped')

# creating fill column
image_df.insert(loc=0, column='card_filename', value='SET0007')

# %%
image_df
# Out:
#   card_filename     fill  number     shape color    0    1    2    3    4  \
# 0       SET0007  striped       3  squiggle   red  255  255  255  255  255
#
#    ...  5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# 0  ...   255   255   255   255   255   255   255   255   255   255
#
# [1 rows x 5255 columns]

# %%
35*50*3
# Out:
# 5250

# %%
df = image_df.copy()

# %%
# filenames= []
i = 0

for filename in os.listdir('./attachments'):
    # get the image
    image = Image.open('./attachments/' + filename)
    
    #crop out white space
    cropped = image.crop((60, 20, 950, 643))
    
    #rescale to 50x35
    basewidth = 50
    wpercent = (basewidth / float(cropped.size[0]))
    hsize = int((float(cropped.size[1]) * float(wpercent)))
    img = cropped.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    
    img.show()
    
    #reshape to vector to be used as row in dataframe
    img_vec = np.array(img)
    img_vec_flat = img_vec.reshape(1,-1)
    
    # creating dataframe
    image_df = pd.DataFrame(img_vec_flat)

    # creating color column
    color = input('color?')
    image_df.insert(loc=0, column='color', value=color)

    # creating shape column
    shape = input('shape?')
    image_df.insert(loc=0, column='shape', value=shape)

    # creating number column
    number = input('number?')
    image_df.insert(loc=0, column='number', value=number)

    # creating fill column
    fill = input('fill?')
    image_df.insert(loc=0, column='fill', value=fill)

    # creating fill column
    image_df.insert(loc=0, column='card_filename', value=filename)
    
    # concatonate with final dataframe
    df = pd.concat([df,image_df], axis = 0)
    
    
    i = i+1
    print(f'done with {i}')
# Out:
# color?purple
# shape?oval
# number?1
# fill?outlined
# done with 1
# color?purple
# shape?diamond
# number?2
# fill?outlined
# done with 2
# color?purple
# shape?diamond
# number?2
# fill?striped
# done with 3
# color?purple
# shape?diamond
# number?3
# fill?outlined
# done with 4
# color?red
# shape?oval
# number?2
# fill?solid
# done with 5
# color?purple
# shape?squiggle
# number?2
# fill?solid
# done with 6
# color?red
# shape?oval
# number?3
# fill?striped
# done with 7
# color?green
# shape?oval
# number?2
# fill?striped
# done with 8
# color?red
# shape?diamond
# number?3
# fill?solid
# done with 9
# color?purple
# shape?oval
# number?2
# fill?solid
# done with 10
# color?green
# shape?oval
# number?1
# fill?solid
# done with 11
# color?green
# shape?squiggle
# number?outlined
# fill?solid
# done with 12
# color?purple
# shape?squiggle
# number?1
# fill?striped
# done with 13
# color?purple
# shape?squiggle
# number?2
# fill?outlined
# done with 14
# color?green
# shape?squiggle
# number?1
# fill?striped
# done with 15
# color?green
# shape?diamond
# number?3
# fill?striped
# done with 16
# color?red
# shape?diamond
# number?2
# fill?solid
# done with 17
# color?green
# shape?squiggle
# number?2
# fill?outlined
# done with 18
# color?green
# shape?oval
# number?2
# fill?solid
# done with 19
# color?green
# shape?oval
# number?3
# fill?outlined
# done with 20
# color?green
# shape?squiggle
# number?3
# fill?solid
# done with 21
# color?red
# shape?squiggle
# number?2
# fill?solid
# done with 22
# color?purple
# shape?diamond
# number?1
# fill?solid
# done with 23
# color?red
# shape?diamond
# number?3
# fill?striped
# done with 24
# color?purple
# shape?squiggle
# number?3
# fill?striped
# done with 25
# color?green
# shape?diamond
# number?1
# fill?
# done with 26
# color?red
# shape?squiggle
# number?2
# fill?striped
# done with 27
# color?red*
# shape?oval
# number?1*
# fill?solid
# done with 28
# color?red
# shape?oval
# number?2
# fill?outliend
# done with 29
# color?red
# shape?diamond
# number?1
# fill?outlined
# done with 30
# color?green
# shape?diamond
# number?3
# fill?solid
# done with 31
# color?red
# shape?diamond
# number?2
# fill?striped
# done with 32
# color?purple
# shape?oval
# number?3
# fill?outlined
# done with 33
# color?green
# shape?diamond
# number?1
# fill?solid
# done with 34
# color?green
# shape?oval
# number?2
# fill?outlined
# done with 35
# color?purple
# shape?squiggle
# number?2
# fill?striped
# done with 36
# color?green
# shape?oval
# number?3
# fill?solid
# done with 37
# color?red
# shape?diamond
# number?2
# fill?outlined
# done with 38
# color?green
# shape?diamond
# number?2
# fill?outlined
# done with 39
# color?green
# shape?diamond
# number?1*
# fill?striped
# done with 40
# color?red
# shape?squiggle
# number?1
# fill?striped
# done with 41
# color?purple
# shape?diamond
# number?1
# fill?striped
# done with 42
# color?red
# shape?oval
# number?3
# fill?outlined
# done with 43
# color?purple
# shape?squiggle
# number?1
# fill?outlined
# done with 44
# color?greem
# shape?squiggle
# number?2
# fill?solid
# done with 45
# color?red
# shape?diamond
# number?1
# fill?striped
# done with 46
# color?red
# shape?diamond
# number?3
# fill?outlined
# done with 47
# color?purple
# shape?diamond
# number?3
# fill?striped
# done with 48
# color?green
# shape?oval
# number?1
# fill?outlined
# done with 49
# color?green
# shape?diamond
# number?2
# fill?solid
# done with 50
# color?purple
# shape?oval
# number?3
# fill?solid
# done with 51
# color?purple
# shape?oval
# number?2
# fill?striped
# done with 52
# color?red
# shape?squiggle
# number?3
# fill?solid
# done with 53
# color?red
# shape?diamond
# number?1
# fill?solid
# done with 54
# color?purple
# shape?squiggle
# number?3
# fill?outlined
# done with 55
# color?purple
# shape?diamond
# number?1
# fill?outlined
# done with 56
# color?green
# shape?diamond
# number?3
# fill?outlined
# done with 57
# color?purple
# shape?squiggle
# number?3
# fill?solid
# done with 58
# color?purple
# shape?oval
# number?2
# fill?outlined
# done with 59
# color?red
# shape?oval
# number?1
# fill?striped
# done with 60
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-168-ac96bb4a22dc> in <module>
#       4 for filename in os.listdir('./attachments'):
#       5     # get the image
# ----> 6     image = Image.open('./attachments/' + filename)
#       7
#       8     #crop out white space
#
# /opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# IsADirectoryError: [Errno 21] Is a directory: './attachments/.ipynb_checkpoints'

# %%
# filenames= []
i = 60

for filename in os.listdir('./attachments/attachments61to81'):
    # get the image
    image = Image.open('./attachments/attachments61to81/' + filename)
    
    #crop out white space
    cropped = image.crop((60, 20, 950, 643))
    
    #rescale to 50x35
    basewidth = 50
    wpercent = (basewidth / float(cropped.size[0]))
    hsize = int((float(cropped.size[1]) * float(wpercent)))
    img = cropped.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    
    img.show()
    
    #reshape to vector to be used as row in dataframe
    img_vec = np.array(img)
    img_vec_flat = img_vec.reshape(1,-1)
    
    # creating dataframe
    image_df = pd.DataFrame(img_vec_flat)

    # creating color column
    color = input('color?')
    image_df.insert(loc=0, column='color', value=color)

    # creating shape column
    shape = input('shape?')
    image_df.insert(loc=0, column='shape', value=shape)

    # creating number column
    number = input('number?')
    image_df.insert(loc=0, column='number', value=number)

    # creating fill column
    fill = input('fill?')
    image_df.insert(loc=0, column='fill', value=fill)

    # creating fill column
    image_df.insert(loc=0, column='card_filename', value=filename)
    
    # concatonate with final dataframe
    df = pd.concat([df,image_df], axis = 0)
    
    
    i = i+1
    print(f'done with {i}')
# Out:
# color?purple
# shape?oval
# number?1
# fill?outlined
# done with 61
# color?purple
# shape?diamond
# number?2
# fill?outlined
# done with 62
# color?purple
# shape?diamond
# number?2
# fill?striped
# done with 63
# color?purple
# shape?diamond
# number?3
# fill?outlined
# done with 64
# color?red
# shape?oval
# number?2
# fill?solid
# done with 65
# color?red
# shape?diamond
# number?3
# fill?solid
# done with 66
# color?purple
# shape?oval
# number?2
# fill?solid
# done with 67
# color?green
# shape?squiggle
# number?1
# fill?outlined
# done with 68
# color?purple
# shape?squiggle
# number?1
# fill?striped
# done with 69
# color?purple
# shape?squiggle
# number?2
# fill?outlined
# done with 70
# color?green
# shape?squiggle
# number?1
# fill?striped
# done with 71
# color?red
# shape?diamond
# number?2
# fill?solid
# done with 72
# color?green
# shape?squiggle
# number?2
# fill?outlined
# done with 73
# color?green
# shape?oval
# number?2
# fill?solid
# done with 74
# color?green
# shape?oval
# number?3
# fill?outlined
# done with 75
# color?green
# shape?squiggle
# number?2
# fill?striped
# done with 76
# color?green
# shape?squiggle
# number?3
# fill?striped
# done with 77
# color?purple
# shape?diamond
# number?2
# fill?solid
# done with 78
# color?red
# shape?oval
# number?2
# fill?striped
# done with 79

# %%
df.head(10)
# Out:
#   card_filename      fill number     shape   color    0    1    2    3    4  \
# 0       SET0007   striped      3  squiggle     red  255  255  255  255  255
# 0   SeT0063.jpg  outlined      1      oval  purple  255  255  255  255  255
# 0   SeT0077.jpg  outlined      2   diamond  purple  255  255  255  255  255
# 0   SeT0076.jpg   striped      2   diamond  purple  255  255  255  255  255
# 0   SeT0062.jpg  outlined      3   diamond  purple  255  255  255  255  255
# 0   SeT0074.jpg     solid      2      oval     red  255  255  255  255  255
# 0   SeT0060.jpg     solid      2  squiggle  purple  255  255  255  255  255
# 0   SeT0048.jpg   striped      3      oval     red  255  255  255  255  255
# 0   SeT0049.jpg   striped      2      oval   green  255  255  255  255  255
# 0   SeT0061.jpg     solid      3   diamond     red  255  255  255  255  255
#
#    ...  5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
#
# [10 rows x 5255 columns]

# %%
df.tail(10)
# Out:
#   card_filename      fill number     shape   color    0    1    2    3    4  \
# 0   SeT0064.jpg  outlined      2  squiggle  purple  255  255  255  255  255
# 0   SeT0070.jpg   striped      1  squiggle   green  255  255  255  255  255
# 0   SeT0066.jpg     solid      2   diamond     red  255  255  255  255  255
# 0   SeT0072.jpg  outlined      2  squiggle   green  255  255  255  255  255
# 0   SeT0073.jpg     solid      2      oval   green  255  255  255  255  255
# 0   SeT0067.jpg  outlined      3      oval   green  255  255  255  255  255
# 0   SeT0069.jpg   striped      2  squiggle   green  255  255  255  255  255
# 0   SeT0068.jpg   striped      3  squiggle   green  255  255  255  255  255
# 0   SeT0078.jpg     solid      2   diamond  purple  255  255  255  255  255
# 0   SeT0079.jpg   striped      2      oval     red  255  255  255  255  255
#
#    ...  5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
# 0  ...   255   255   255   255   255   255   255   255   255   255
#
# [10 rows x 5255 columns]

# %%
df['card_filename'].value_counts()
# Out:
# SeT0073.jpg    2
# SeT0074.jpg    2
# SeT0072.jpg    2
# SeT0066.jpg    2
# SeT0075.jpg    2
#               ..
# SeT0034.jpg    1
# SeT0024.jpg    1
# SET0007.jpg    1
# SeT0079.jpg    1
# SET0009.jpg    1
# Name: card_filename, Length: 65, dtype: int64

# %%
df[df['card_filename']== 'SeT0073.jpg']
# Out:
#   card_filename   fill number shape  color    0    1    2    3    4  ...  \
# 0   SeT0073.jpg  solid      2  oval  green  255  255  255  255  255  ...
# 0   SeT0073.jpg  solid      2  oval  green  255  255  255  255  255  ...
#
#    5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# 0   255   255   255   255   255   255   255   255   255   255
# 0   255   255   255   255   255   255   255   255   255   255
#
# [2 rows x 5255 columns]

# %%
df['color'].value_counts()
# Out:
# purple    29
# green     26
# red       23
# red*       1
# greem      1
# Name: color, dtype: int64

# %%
df['shape'].value_counts()
# Out:
# diamond     30
# squiggle    25
# oval        25
# Name: shape, dtype: int64

# %%
df['number'].value_counts()
# Out:
# 2           33
# 3           23
# 1           20
# 1*           2
# outlined     1
# 3            1
# Name: number, dtype: int64

# %%
len(filenames)
# Out:
# 81

# %%
df.shape
# Out:
# (80, 5255)

# %%
df.to_csv('SET_data.csv')

# %%
filenames = []
for filename in os.listdir('./attachments'):
    filenames.append(filename)
    
for filename in os.listdir('./attachments/attachments61to81'):
    filenames.append(filename)

# %%
filenames_set = set(filenames)

# %%
df_set = set(df['card_filename'])

# %%
diff = np.setdiff1d(filenames_set, df_set)

# %%
len(diff[0])
# Out:
# 83

# %%
len(df['card_filename'])
# Out:
# 80

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (66, 5255)

# %%
df_set = set(df['card_filename'])
filenames_set = set(filenames)

# %%
diff = filenames_set.difference(df_set)

# %%
diff.remove('.DS_Store')
diff.remove('.ipynb_checkpoints')
diff.remove('attachments61to81')

# %%
diff
# Out:
# {'SeT0040.jpg',
#  'SeT0041.jpg',
#  'SeT0042.jpg',
#  'SeT0043.jpg',
#  'SeT0044.jpg',
#  'SeT0045.jpg',
#  'SeT0046.jpg',
#  'SeT0047.jpg',
#  'SeT0050.jpg',
#  'SeT0051.jpg',
#  'SeT0052.jpg',
#  'SeT0053.jpg',
#  'SeT0054.jpg',
#  'SeT0055.jpg',
#  'SeT0056.jpg',
#  'SeT0057.jpg'}

# %%
# filenames= []
i = 0

for filename in diff:
    # get the image
    image = Image.open('./attachments/' + filename)
    
    #crop out white space
    cropped = image.crop((60, 20, 950, 643))
    
    #rescale to 50x35
    basewidth = 50
    wpercent = (basewidth / float(cropped.size[0]))
    hsize = int((float(cropped.size[1]) * float(wpercent)))
    img = cropped.resize((basewidth, hsize), PIL.Image.ANTIALIAS)
    
    img.show()
    
    #reshape to vector to be used as row in dataframe
    img_vec = np.array(img)
    img_vec_flat = img_vec.reshape(1,-1)
    
    # creating dataframe
    image_df = pd.DataFrame(img_vec_flat)

    # creating color column
    color = input('color?')
    image_df.insert(loc=0, column='color', value=color)

    # creating shape column
    shape = input('shape?')
    image_df.insert(loc=0, column='shape', value=shape)

    # creating number column
    number = input('number?')
    image_df.insert(loc=0, column='number', value=number)

    # creating fill column
    fill = input('fill?')
    image_df.insert(loc=0, column='fill', value=fill)

    # creating fill column
    image_df.insert(loc=0, column='card_filename', value=filename)
    
    # concatonate with final dataframe
    df = pd.concat([df,image_df], axis = 0)
    
    
    i = i+1
    print(f'done with {i}')
# Out:
# color?red
# shape?squiggle
# number?1
# fill?outlined
# done with 1
# color?green
# shape?oval
# number?1
# fill?striped
# done with 2
# color?purple
# shape?oval
# number?1
# fill?solid
# done with 3
# color?red
# shape?squiggle
# number?1
# fill?solid
# done with 4
# color?purple
# shape?oval
# number?1
# fill?striped
# done with 5
# color?purple
# shape?oval
# number?3
# fill?striped
# done with 6
# color?red
# shape?squiggle
# number?3
# fill?outlined
# done with 7
# color?red
# shape?squiggle
# number?2
# fill?outlined
# done with 8
# color?green
# shape?oval
# number?3
# fill?striped
# done with 9
# color?red
# shape?squiggle
# number?3
# fill?striped
# done with 10
# color?purple
# shape?squiggle
# number?1
# fill?solid
# done with 11
# color?purple
# shape?diamond
# number?3
# fill?solid
# done with 12
# color?green
# shape?squiggle
# number?1
# fill?solid
# done with 13
# color?red
# shape?oval
# number?1
# fill?outlined
# done with 14
# color?red
# shape?oval
# number?3
# fill?solid
# done with 15
# color?green
# shape?diamond
# number?2
# fill?striped
# done with 16

# %%
df.shape
# Out:
# (82, 5255)

# %% [markdown]
# # Cleanup

# %%
df['color'].value_counts()
# Out:
# green     27
# red       27
# purple    27
# red*       1
# Name: color, dtype: int64

# %%
df[df['color']=='greem']
# Out:
#   card_filename   fill number     shape  color    0    1    2    3    4  ...  \
# 0   SeT0034.jpg  solid      2  squiggle  greem  255  255  255  255  255  ...
#
#    5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# 0   255   255   255   255   255   255   255   255   255   255
#
# [1 rows x 5255 columns]

# %%
df.replace({'greem':'green'},inplace = True)

# %%
df['shape'].value_counts()
# Out:
# squiggle    28
# oval        27
# diamond     27
# Name: shape, dtype: int64

# %%
# there is an extra squiggle card

# %%
df.to_csv('SET_data2.csv')

# %%
df['number'].value_counts()
# Out:
# 2           27
# 3           26
# 1           25
# 1*           2
# outlined     1
# 3            1
# Name: number, dtype: int64

# %%
df[df['number']=='1*']
# Out:
#   card_filename     fill number    shape  color    0    1    2    3    4  ...  \
# 0   SET0002.jpg    solid     1*     oval   red*  255  255  255  255  255  ...
# 0       SET.jpg  striped     1*  diamond  green  255  255  255  255  255  ...
#
#    5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# 0   255   255   255   255   255   255   255   255   255   255
# 0   255   255   255   255   255   255   255   255   255   255
#
# [2 rows x 5255 columns]

# %%
df.replace({'1*':1, 'red*':'red'}, inplace = True)

# %%
df[df['number']=='outlined']
# Out:
#                 fill    number     shape  color    0    1    2    3    4    5  \
# card_filename
# SeT0071.jpg    solid  outlined  squiggle  green  255  255  255  255  255  255
#
#                ...  5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# card_filename  ...
# SeT0071.jpg    ...   255   255   255   255   255   255   255   255   255   255
#
# [1 rows x 5254 columns]

# %%
df.loc['SeT0071.jpg']
# Out:
#                    fill    number     shape  color    0    1    2    3    4  \
# card_filename
# SeT0071.jpg       solid  outlined  squiggle  green  255  255  255  255  255
# SeT0071.jpg    outlined         1  squiggle  green  255  255  255  255  255
#
#                  5  ...  5240  5241  5242  5243  5244  5245  5246  5247  5248  \
# card_filename       ...
# SeT0071.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0071.jpg    255  ...   255   255   255   255   255   255   255   255   255
#
#                5249
# card_filename
# SeT0071.jpg     255
# SeT0071.jpg     255
#
# [2 rows x 5254 columns]

# %%
df = df[df.number != 'outlined']

# %%
df.set_index('card_filename', inplace = True)

# %%
df['number'].value_counts()
# Out:
# 2    27
# 3    26
# 1    25
# 1     2
# 3     1
# Name: number, dtype: int64

# %%
set(df['number'])
# Out:
# {1, '1', '2', 3, '3'}

# %%
df['number'] = df['number'].astype(int)

# %%
df['number'].value_counts()
# Out:
# 3    27
# 2    27
# 1    27
# Name: number, dtype: int64

# %%
df['shape'].value_counts()
# Out:
# squiggle    27
# oval        27
# diamond     27
# Name: shape, dtype: int64

# %%
df['color'].value_counts()
# Out:
# red       28
# purple    27
# green     26
# Name: color, dtype: int64

# %%
df['fill'].value_counts()
# Out:
# striped     28
# solid       27
# outlined    24
# outliend     1
#              1
# Name: fill, dtype: int64

# %%
df.replace({'outliend':'outlined'}, inplace = True)

# %%
df['fill'].value_counts()
# Out:
# striped     28
# solid       27
# outlined    25
#              1
# Name: fill, dtype: int64

# %%
set(df['fill'])
# Out:
# {'', 'outlined', 'solid', 'striped'}

# %%
df[df['fill']=='']
# Out:
#               fill  number    shape  color    0    1    2    3    4    5  ...  \
# card_filename                                                             ...
# SET0017.jpg              1  diamond  green  255  255  255  255  255  255  ...
#
#                5240  5241  5242  5243  5244  5245  5246  5247  5248  5249
# card_filename
# SET0017.jpg     255   255   255   255   255   255   255   255   255   255
#
# [1 rows x 5254 columns]

# %%
df.replace({'':'outlined'}, inplace = True)

# %%
df['fill'].value_counts()
# Out:
# striped     28
# solid       27
# outlined    26
# Name: fill, dtype: int64

# %%
df[df['fill']=='striped']
# Out:
#                   fill  number     shape   color    0    1    2    3    4  \
# card_filename
# SET0007        striped       3  squiggle     red  255  255  255  255  255
# SeT0076.jpg    striped       2   diamond  purple  255  255  255  255  255
# SeT0048.jpg    striped       3      oval     red  255  255  255  255  255
# SeT0049.jpg    striped       2      oval   green  255  255  255  255  255
# SeT0065.jpg    striped       1  squiggle  purple  255  255  255  255  255
# SeT0070.jpg    striped       1  squiggle   green  255  255  255  255  255
# SeT0058.jpg    striped       3   diamond   green  255  255  255  255  255
# SET0015.jpg    striped       3   diamond     red  255  255  255  255  255
# SET0001.jpg    striped       3  squiggle  purple  255  255  255  255  255
# SET0003.jpg    striped       2  squiggle     red  255  255  255  255  255
# SET0007.jpg    striped       2   diamond     red  255  255  255  255  255
# SET0011.jpg    striped       2  squiggle  purple  255  255  255  255  255
# SET.jpg        striped       1   diamond   green  255  255  255  255  255
# SeT0021.jpg    striped       1  squiggle     red  255  255  255  255  255
# SeT0035.jpg    striped       1   diamond  purple  255  255  255  255  255
# SeT0020.jpg    striped       1   diamond     red  255  255  255  255  255
# SeT0022.jpg    striped       3   diamond  purple  255  255  255  255  255
# SeT0027.jpg    striped       2      oval  purple  255  255  255  255  255
# SET0019.jpg    striped       1      oval     red  255  255  255  255  255
# SeT0069.jpg    striped       2  squiggle   green  255  255  255  255  255
# SeT0068.jpg    striped       3  squiggle   green  255  255  255  255  255
# SeT0079.jpg    striped       2      oval     red  255  255  255  255  255
# SeT0046.jpg    striped       1      oval   green  255  255  255  255  255
# SeT0047.jpg    striped       1      oval  purple  255  255  255  255  255
# SeT0057.jpg    striped       3      oval  purple  254  254  254  255  255
# SeT0051.jpg    striped       3      oval   green  255  255  255  255  255
# SeT0056.jpg    striped       3  squiggle     red  255  255  255  255  255
# SeT0041.jpg    striped       2   diamond   green  255  255  255  255  255
#
#                  5  ...  5240  5241  5242  5243  5244  5245  5246  5247  5248  \
# card_filename       ...
# SET0007        255  ...   255   255   255   255   255   255   255   255   255
# SeT0076.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0048.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0049.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0065.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0070.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0058.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET0015.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET0001.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET0003.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET0007.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET0011.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET.jpg        255  ...   255   255   255   255   255   255   255   255   255
# SeT0021.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0035.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0020.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0022.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0027.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SET0019.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0069.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0068.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0079.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0046.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0047.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0057.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0051.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0056.jpg    255  ...   255   255   255   255   255   255   255   255   255
# SeT0041.jpg    255  ...   255   255   255   255   255   255   255   255   255
#
#                5249
# card_filename
# SET0007         255
# SeT0076.jpg     255
# SeT0048.jpg     255
# SeT0049.jpg     255
# SeT0065.jpg     255
# SeT0070.jpg     255
# SeT0058.jpg     255
# SET0015.jpg     255
# SET0001.jpg     255
# SET0003.jpg     255
# SET0007.jpg     255
# SET0011.jpg     255
# SET.jpg         255
# SeT0021.jpg     255
# SeT0035.jpg     255
# SeT0020.jpg     255
# SeT0022.jpg     255
# SeT0027.jpg     255
# SET0019.jpg     255
# SeT0069.jpg     255
# SeT0068.jpg     255
# SeT0079.jpg     255
# SeT0046.jpg     255
# SeT0047.jpg     255
# SeT0057.jpg     255
# SeT0051.jpg     255
# SeT0056.jpg     255
# SeT0041.jpg     255
#
# [28 rows x 5254 columns]

# %%
df.duplicated().value_counts()
# Out:
# False    81
# dtype: int64

# %%
df.to_csv('final_SET.csv')
